# %%
import requests

# %%
response = requests.get("https://api.github.com/repos/Aakashtyagi9889/Projects-/branches",
     headers = {
     "Accept": "application/vnd.github+json",
    "Authorization": "Bearer {your tokken}",
    "X-GitHub-Api-Version": "2022-11-28"
})

response.json()

# %%
from dotenv import load_dotenv
import os
import requests

load_dotenv()
print(os.getenv("pat"))

# %%
pip install databricks.sdk

# %%
from databricks.sdk import WorkspaceClient

# %%
w = WorkspaceClient() 
w.secrets.create_scope(scope="batch3")

# %%
w.secrets.list_scopes()

# %%
w.secrets.put_secret(scope="batch3", key="pat",string_value=dbutils.widgets.get("pat1"))

# %%
dbutils.widgets.text("pat1","Enter_value")

# %%
import requests
response = requests.get("https://api.github.com/repos/Aakashtyagi9889/Projects-/branches",
     headers = {
     "Accept": "application/vnd.github+json",
    "Authorization": "Bearer "+ dbutils.secrets.get(scope="batch3",key="pat"),
    "X-GitHub-Api-Version": "2022-11-28"
})
response.json()

# %%
response = requests.get("https://api.github.com/repos/Aakashtyagi9889/Data-Engineering-A_K/branches",
     headers = {
     "Accept": "application/vnd.github+json",
    "Authorization": "Bearer " + dbutils.secrets.get(scope="batch3",key="pat"),
    "X-GitHub-Api-Version": "2022-11-28"
})

response.json()

# %% [markdown]
# # **Do it again by os.getenv**
