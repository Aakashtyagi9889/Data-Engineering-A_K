# %% [markdown]
# # Python Programming Language
#
# ## Overview
# Python is a high-level, interpreted, and general-purpose programming language created by Guido van Rossum and first released in 1991. It emphasizes code readability with its notable use of significant whitespace.
#
# ## Key Features
# * **Easy to Learn**: Simple, clean syntax that resembles natural language
# * **Abstraction level**: High level Language
# * **Interpreted**: Code is executed line by line, making debugging easier
# * **Dynamically Typed**: No need to declare variable types explicitly
# * **Multi-paradigm**: Supports procedural, object-oriented, and functional programming
# * **Extensive Libraries**: Rich ecosystem with packages for data science, web development, automation, and more
# * **Cross-platform**: Runs on Windows, macOS, Linux, and other operating systems
#
# ## Popular Use Cases
# * Data Science & Machine Learning (pandas, NumPy, scikit-learn, TensorFlow)
# * Web Development (Django, Flask, FastAPI)
# * Automation & Scripting
# * Data Engineering (PySpark, Apache Airflow)
# * Scientific Computing
# * API Development
#
# ## In Databricks
# Python is one of the primary languages in Databricks, used for:
# * PySpark data processing
# * Machine learning workflows with MLflow
# * Delta Lake operations
# * Notebook-based analytics and visualization

# %%
#Data Types in python -->String , list , tuples , set , dict 
# string =  It store alphanumeric text
# Features - Mutability -------->Immutable
a = "I Love DE 101"
type(a)

print(a[3]) #INDEXING
print(a[-6]) # REVERSE INDEXING
print(a[7:9]) # Slicing 
print(a[0:13:2]) 
print(a[-3:]) # Reverse Slicing 
print(a[-6:-4])

# Reverse the string  (Interview Question)
print(a[::-1])

# Love ==> evoL
print(a[-8:-12  :-1])
# without using negative slicing
print(a[2:6][::-1])

# %%
# Iterable

a = "ABC"

for j in a:
    if  j =='B':
        print(j)
    else:
        print("_")




# Use Case 
#Get all the vowels out of this string
#"Our eerie audio engineer, Louie, queueing via a radio, queued an awesome sequoia avenue video."

# %%
a = "Our eerie audio engineer, Louie, queueing via a radio, queued an awesome sequoia avenue video"
r = 0
for i in a:
    if i in "aeiou":
        print(i)
        r = r+1
    else:
        print("Not a vowel ")
print(r)

# %%
#string methods


A= '   I love DE   '

#UPPER() /LOWER() /capitalize()/ Title()

print(A.upper())
print(A.lower())
print(A.capitalize())
print(A.title())

#strip() /rstrip() /lstrip()

print(A.strip())
print(A.rstrip())
print(A.lstrip())

#replace()

print(A.replace("love","hate"))

#split()

print(A.split())

#join()

print()

# %%
#spliting

st = 'My Name is AK'
st2 = '1,2,3,4,5,6,7,8'
print(st.split())
print(st2.split(","))

#join()
A = ['Ball','Cat','Dog']
print("-".join(A))
#String Methods

#1. String (Indexing /Slicing)
#2. Iterable())

# %%
# F- string
from datetime import datetime as dt

time = dt.now()

print(time)


print(f"Current Time is {time}")

# %%
# Lists

L = [1,2,3,"ASDA","sdFDS"]
#MUTABLE (append,insert,extend,remove,pop,clear, del)

L.append("New")
print(L)
L.insert(2,"New")
print(L)
L.remove("New")
print(L)
L.pop()
print(L)
L.clear()
print(L)
#del L
#print(L)




#Sequential

# %%
#ITERABLE
L = [1,2,3,"ASDA","sdFDS"]
for j in L:
    print(j)

# %%
#Scenario

## You have a string , get all the words in a list with length of 5 chars.
st ="Our eerie audio engineer, Louie, queueing via a radio, queued an awesome sequoia avenue video."
st = st.replace(",","")
st_list = st.split()
L = []
for i in st_list:
    if len(i) == 5:
          L.append(i)

print(len(L))

# %%
# functions
def count_5(st,x,delimiter):
    st = st.replace(delimiter,"")
    st_list = st.split()
    L = []
    for i in st_list:
        if len(i) == x:
          L.append(i)

    print(len(L))

# %%
count_5("I love rrrr; yyyy; DEeeeee ddssg",4,";")

# %%
#multi indexing
L = [1,2,3,4,"Kanishk","Gautam","Deepali"]

L[4][::-1]

# %%
print('test')

# %% [markdown]
# #Dictionary

# %%
d = {
    "Name" : ["Kanishk","Gautam","Deepali","anirudh"],
    "Age" : [23,24,21,23],
}
import pandas as pd
df = pd.DataFrame(d)
display(df)

# %%
# Dictionary Properties
# 1. keys must be unique
# 2. keys must be immutable
# 3. values can be mutable
# 4. values can be anything / duplicate

d.keys()
d.values()
d.items()
d.get("Name")

# %%
# Sample dictionary
sample_dict = {
    "name": "John Doe",
    "age": 30,
    "city": "San Francisco",
    "skills": ["Python", "SQL", "Spark"],
    "is_active": True
}

print(sample_dict)

# %%
# sample_dict.pop('skills')

# %%
for i in sample_dict:
    print(i)

# %%
for i in sample_dict.keys():
    print(i)

# %%
for i , j in sample_dict.items():
    print(i , j)

# %%
for i in sample_dict.values():
    print(i)

# %%
nested_dict = {
    "person1": {
        "name": "Anirudh",
        "age": 23,
        "city": "Delhi"
    },
    "person2": {
        "name": "Kanishk",
        "age": 34,
        "city": "Mumbai"
    }
}

# print(nested_dict['person2']['age'])
# nested_dict.get('person1')
nested_dict.get("person3")
# print(nested_dict['person3'])
nested_dict['person2']= {
        "name": "Kanishk",
        "age": 21
    }

nested_dict.update( {"person1": {
        "name": "Ani",
        "age": 23,
        "city": "Noida"
    }, 
    "person3": {
        "name": "Nishi",
        "age": 23,
        "city": "Pune"
    }})

nested_dict

# %%
# it will help to set default value if it does not exist but it updates in dictionary as well("Not Found")
nested_dict.setdefault("person4", "Not Found")
nested_dict

# %%
# import pandas as pd
# df = pd.DataFrame(nested_dict)
# df

# %%
nested_dict.fromkeys(["person1" , "person2" ])

#  ye keys nikalne k lie kaam aata hai or [] k andar dena hota 
# we can give also default value 
nested_dict.fromkeys(["person1" , "person2" ] , "unknown")
# use case: 
    # ye jab use hota hai jab hame keys chie ho bas values nahi chie ho ex: copy dictionary structure 
    #  Existing dictionary se template copy karne ka kaam hota hai
# Fromkeys() se dictionary mai duplicate values remove hosakti hai . 

L = [1,1,1,1,2,2,2,3,3,4,4]
d3 = dict.fromkeys(L , "Default VALUE")
d3

# %%
list(d3)

# %%
#  Existing dictionary se template copy karne ka kaam hota hai
nested_dict_template = nested_dict.fromkeys(nested_dict.keys())
# nested_dict_template = dict.fromkeys(nested_dict.keys())
nested_dict_template

# %% [markdown]
# ##Ingesting Data from Different Sources

# %%
# Databricks supports ingesting data from many sources:

# 1. Cloud Storage (Native support)
#    - Azure Blob Storage / Azure Data Lake Storage (ADLS)
#    - AWS S3
#    - Google Cloud Storage (GCS)

# 2. Databases (via JDBC/ODBC or native connectors)
#    - MySQL
#    - PostgreSQL
#    - SQL Server
#    - Oracle
#    - Snowflake
#    - Azure SQL Database
#    - Amazon Redshift


# 4. Streaming Sources (Databricks)
#    - Apache Kafka
#    - Azure Event Hubs
#    - AWS Kinesis
#    - Delta Live Tables (streaming)

# 5. Files (various formats)
#    - CSV, JSON, Parquet, Avro, ORC
#    - Delta Lake
#    - XML
#    - Excel (with libraries)

# 6. APIs
#    - REST APIs (using requests library)
#    - Third-party APIs with Python SDKs

# 7. Other Sources
#    - MongoDB
#    - Cassandra
#    - Elasticsearch
#    - Delta Sharing (data sharing across organizations)

# %%
# ingesting csvs
# using csv module
import csv

with open("/Workspace/Users/avityagi9889@gmail.com/Data-Engineering-A_K/.git/users_dirty.csv",'r') as csv_file:
    csv_reader = csv.reader(csv_file)
    for i in csv_reader:
        print(i)
print(csv_reader)
# type(csv_reader) # special type because we use csv module

# %%
import pandas as pd 

df = pd.read_csv("/Workspace/Users/avityagi9889@gmail.com/Data-Engineering-A_K/.git/users_dirty.csv")
df.display()

# %%
# append data using import csv module 
import csv

data = ['USR_1099', 'Graceew', 'Wilson', 'grace.wilson2@example.com', '3/21/22', 'US', 'organic']

with open("/Workspace/Users/avityagi9889@gmail.com/Data-Engineering-A_K/.git/users_dirty.csv" , 'a') as csv_file:
    csv_reader = csv.writer(csv_file)
    csv_reader.writerow(data)

# %%
#  check data is succesfully append or not 
import pandas as pd
df = pd.read_csv("/Workspace/Users/avityagi9889@gmail.com/Data-Engineering-A_K/.git/users_dirty.csv")
# using pandas
df.tail()

# %%
# Different methods and modes for reading CSV in pandas

import pandas as pd

# 1. Basic read_csv
df = pd.read_csv('file.csv')

# 2. Common parameters:

# Delimiter/separator
df = pd.read_csv('file.csv', sep=',')  # default comma
df = pd.read_csv('file.tsv', sep='\t')  # tab-separated
df = pd.read_csv('file.txt', delimiter='|')  # pipe-separated

# Header options
df = pd.read_csv('file.csv', header=0)  # first row as column names (default)
df = pd.read_csv('file.csv', header=None)  # no header row
df = pd.read_csv('file.csv', names=['col1', 'col2', 'col3'])  # specify column names

# Index column
df = pd.read_csv('file.csv', index_col=0)  # use first column as index
df = pd.read_csv('file.csv', index_col='id')  # use specific column as index

# Data types
df = pd.read_csv('file.csv', dtype={'col1': str, 'col2': int})
df = pd.read_csv('file.csv', dtype=str)  # all columns as strings

# Handle missing values
df = pd.read_csv('file.csv', na_values=['NA', 'null', ''])  # specify NA values
df = pd.read_csv('file.csv', keep_default_na=False)  # don't convert to NaN

# Skip rows
df = pd.read_csv('file.csv', skiprows=5)  # skip first 5 rows
df = pd.read_csv('file.csv', skiprows=[0, 2, 4])  # skip specific rows
df = pd.read_csv('file.csv', skipfooter=3)  # skip last 3 rows

# Read specific columns
df = pd.read_csv('file.csv', usecols=['col1', 'col3'])  # by name
df = pd.read_csv('file.csv', usecols=[0, 2, 4])  # by index

# Parse dates
df = pd.read_csv('file.csv', parse_dates=['date_column'])
df = pd.read_csv('file.csv', parse_dates={'datetime': ['date', 'time']})

# Encoding
df = pd.read_csv('file.csv', encoding='utf-8')  # default
df = pd.read_csv('file.csv', encoding='latin-1')


### utf-8 is the default encoding for pandas.read_csv. If your file is encoded in a different format, you can specify the encoding using the encoding parameter.
##special Char. 

## latin-1


## Dealing with Excel - cp1252




# Chunking (for large files)
chunk_iter = pd.read_csv('large_file.csv', chunksize=10000)
for chunk in chunk_iter:
    print(chunk.shape)  # process each chunk

# Number of rows
df = pd.read_csv('file.csv', nrows=100)  # read only first 100 rows

# Compression
df = pd.read_csv('file.csv.gz', compression='gzip')
df = pd.read_csv('file.csv.zip', compression='zip')
df = pd.read_csv('file.csv', compression='infer')  # auto-detect (default)

# Quoting
df = pd.read_csv('file.csv', quotechar='"')  # default
df = pd.read_csv('file.csv', quoting=0)  # QUOTE_MINIMAL

# Low memory mode
df = pd.read_csv('file.csv', low_memory=False)  # read entire file at once

# Error handling
df = pd.read_csv('file.csv', error_bad_lines=False)  # skip bad lines (deprecated)
df = pd.read_csv('file.csv', on_bad_lines='skip')  # skip bad lines (new)
df = pd.read_csv('file.csv', on_bad_lines='warn')  # warn on bad lines

# Engine
df = pd.read_csv('file.csv', engine='c')  # C engine (faster, default)
df = pd.read_csv('file.csv', engine='python')  # Python engine (more features)

# Converters
df = pd.read_csv('file.csv', converters={'col1': lambda x: x.upper()})

# Comments
df = pd.read_csv('file.csv', comment='#')  # skip lines starting with #

print("CSV reading methods and modes demonstrated!")

# %%
df.info()
df.describe()

# %%
#  convert object/string to datatime by using parse_dates
import pandas as pd
df = pd.read_csv("/Workspace/Users/avityagi9889@gmail.com/Data-Engineering-A_K/.git/users_dirty.csv", parse_dates=['signup_date'])
df.info()

# %%
chunk  = pd.read_csv("/Workspace/Users/avityagi9889@gmail.com/Data-Engineering-A_K/.git/users_dirty.csv", chunksize=5)
for i in chunk:
    print(i.head())

# %%
# df = pd.read_csv('/Workspace/Users/avityagi9889@gmail.com/Data-Engineering-A_K/.git/users_dirty.csv')
# def clean(x):
#     return x.strip().lower()
# df = pd.read_csv('/Workspace/Users/avityagi9889@gmail.com/Data-Engineering-A_K/.git/users_dirty.csv',
#                  converters = {'ProductNumber': clean})



# def clean2(x):
#        return [i.upper() for  i  in x]


# df.columns= clean2(df.columns)

# %% [markdown]
# # API's = Application Programming Interface

# %%
    #apis

#REST - GET, POST,  PUT , DELETE  --- JSON
#GRAPH API - OUTLOOK API
#SOAP - XML


#WEB API
# DB API
#Library API - openpyxl

# API KEY/Token -  5J65TYGFVTJ676TYU7KTRYRTYUGYJ6TKUHJ
# Bearer Token (JWT) 3 day Expiry -  user creds
#   Oauth 2.0 - 3rd party app


import requests

# %%
#1xx - Informational
#2xx - Success
#3xx - Redirection
#4xx - Client Error
#5xx - Server Error
import requests

response = requests.get("https://wttr.in/Delhi?format=j1")
print(response)

data = response.json()
print(data)

# %%
d = data['current_condition'][0]
type(d)

for i , j in d.items():
    print(i,j)

# %%
# dbutils.library.restartPython()
# pip install emoji
import requests
import emoji as e

response = requests.get("https://wttr.in/Delhi?format=3")
print(response)

data = response.text
# print(data)

li = []
res = e.demojize(data)
li.append(res) 
print(li)

# HomeWork 
for i in li:
    print(i[0:5] , " : " ,  i[-6:])

# %%
import pandas as pd

# Method 1: Create an empty DataFrame and save as CSV
df = pd.DataFrame()
df.to_csv("blank1.csv", index=False)

# Method 2: Create a DataFrame with just headers and save as CSV
df2 = pd.DataFrame(columns=['col1', 'col2'])
df2.to_csv("blank2.csv", index=False)

# Method 3: Write an empty CSV file using pandas, no DataFrame
pd.DataFrame().to_csv("blank3.csv", index=False)

# Method 4: Create CSV file with no rows but specify columns directly in DataFrame constructor
df3 = pd.DataFrame(columns=['A', 'B', 'C'])
df3.to_csv("blank4.csv", index=False)

# %% [markdown]
# #Tokken API github

# %%
import requests

response = requests.get("https://api.github.com/repos/Aakashtyagi9889/Data-Engineering-A_K/branches" ,
                        headers = {
    # 1. Authentication header
    # "Authorization": "Bearer you give your tokken here  ",

        "Authorization": "Bearer " + dbutils.secrets.get(scope="batch3", key="pat"),
    
    # 2. Recommended media type to receive responses in JSON format
    "Accept": "application/vnd.github+json",
    
    # 3. Explicitly setting the GitHub API version
    "X-GitHub-Api-Version": "2022-11-28"
})
data = response.json()
data

# %%
response.headers

# %%
# Password/tokens storage within databricks / python

# %%
pip install python-dotenv

# %%
import os 
from dotenv import load_dotenv

load_dotenv() #now it can go and find all the environment file( like .env files)
print(os.getenv("pat"))  # ye getenv kya krega sari file ko search karega aur usme se pat key ko value nikal lega
# import requests

# response = requests.get("https://api.github.com/repos/Aakashtyagi9889/Data-Engineering-Projects/commits", headers={"Authorization": f"Bearer {os.getenv('GITHUB_TOKEN')}"})
# print(response.json(

# %%
os.getcwd()
os.listdir()

# %% [markdown]
# ##Databricks View

# %%
dbutils.help()

# %%
pip install databricks-sdk

# %%
dbutils.library.restartPython()

# %%
from databricks.sdk import WorkspaceClient

w = WorkspaceClient()
w.secrets.create_scope(scope='batch3')

# %%
for i in w.secrets.list_scopes():
    print(i)

# %%
dbutils.widgets.text("pat1","pat2")

# %%
# w.secrets.put_secret(scope='batch3', key='pat',string_value="you put your tokken github restriction")

w.secrets.put_secret(scope='batch3', key='pat',string_value=dbutils.widgets.get("pat1"))

# %% [markdown]
# ##AWS Intro (bucket)

# %%
#connect to a cloud storage like S3 (object) or Azure Blob Storage (blob)
#Hierarchy

# S3>>>Bucket >>> Directories >> objects (files)

import boto3
s3 = boto3.client("s3", aws_access_key_id = "" , aws_secret_access_key = "" , region_name = "us-west-2")

response = s3.list_buckets()
response

# %%
# pip install openpyxl     
import boto3
import pandas as pd 
import io

s3 = boto3.client("s3", aws_access_key_id="" , aws_secret_access_key="" , region_name = "us-west-2")
response = s3.get_object(Bucket='demode2246', Key='superstore.xlsx')
df =  pd.read_excel(io.BytesIO(response['Body'].read()))
df
